# %% [markdown]
# # Documentation and examples for the IPmag.py function library

# %% [markdown]
# IPmag.py is a function library for paleomagnetic data analysis and plotting developed for interactive use within IPython notebooks. The IPmag.py library relies on the pmag.py and pmagplotlib.py libraries of the PmagPy project (https://github.com/ltauxe/PmagPy) and adds new functions and modifies stand alone PmagPy programs for use in the interactive IPython environment. The pmag.py library is included in the IPmag.py repository as a very slightly modified version from that availible in the main PmagPy repository.

# %%
import pmag, pmagplotlib, IPmag
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Examples of pmag.py and IPmag.py functions in action

# %% [markdown]
# ## Using the dipole equation to calculate latitude from paleomagnetic inclination and expected inclination from latitude (`IPmag.inc_from_lat`; `IPmag.lat_from_inc`)

# %% [markdown]
# A geocentric axial dipole magnetic field leads to a simple relationship between inclination and paleolatitude given by the dipole equation: $$\mathrm{tan}(inclination)=2\mathrm{tan}(latitude)$$
#
# `IPmag.inc_from_lat` and `IPmag.lat_from_inc` are simple functions that give inclination for a given latitude or latitude for a given inclination using the dipole equation.

# %% [markdown]
# The functions can be used interactively to give a result for a specified value. For example, what is the predicted latitude of an inclination of 45º?

# %%
IPmag.lat_from_inc(45)
# Out:
# 26.56505117707799

# %% [markdown]
# The function can also take an array of numbers as an input. In the example below, the numpy linspace function is used to create an array of paleolatitudes between 0º and 90º with 0.1º spacing. That array is than put into the `IPmag.inc_from_lat` function to return a corresponding array of inclinations predicted from those latitudes using the dipole formula. A simple plot is then generated of the paleolatitudes and corresponding inclinations for a 100% dipole field.

# %%
paleolatitude=np.linspace(0,90,901)
inclination=IPmag.inc_from_lat(paleolatitude)

plt.plot(inclination,paleolatitude)
plt.xlabel("inclination (degrees)")
plt.ylabel("paleolatitude (degrees)")
plt.title("Inclination as a function of latitude (100% dipole)")
plt.show()

# %% [markdown]
# ## Example of generating a Fisher distributed data set (`IPmag.ifishrot`) and plotting directional data on an equal area plot (`IPmag.iplotDI`)

# %% [markdown]
# In order to demonstrate plotting directional data, let's use the `IPmag.ifishrot` function to generate a list of unit vectors coming from a Fisher distribution with a specified kappa. The `IPmag.ifishrot` function can take four input parameters:
#
#     k : kappa precision parameter (default is 20)
#     n : number of vectors to determine (default is 100)
#     Dec : mean declination of data set (default is 0)
#     Inc : mean inclination of data set (default is 90)

# %%
data = IPmag.ifishrot(k=20,n=20,Dec=0,Inc=90)
print data
# Out:
# [[358.15955896970331, 78.202266600157216, 1.0], [217.86118692597051, 85.355305934372268, 1.0], [84.996381218191914, 66.885754424747617, 1.0], [169.44458736562888, 67.598993679745703, 1.0], [120.88634593939025, 78.377652442908456, 1.0], [98.719029983471387, 77.952050734143867, 1.0], [273.02233865591018, 80.8313949761381, 1.0], [216.64782072414749, 74.638052822560198, 1.0], [162.16206181729956, 63.868363605599285, 1.0], [358.95069866500694, 80.881068315791794, 1.0], [276.85780963662592, 74.507635332057021, 1.0], [0.089475265521400615, 63.399505882564121, 1.0], [168.46620093409706, 79.916360466744493, 1.0], [274.61063808097458, 66.963496091116369, 1.0], [354.85269868947864, 67.362773605373192, 1.0], [194.92359134433156, 75.908225368400082, 1.0], [258.53617446033064, 59.288917517388356, 1.0], [278.54609612429613, 66.784631737975403, 1.0], [136.11304392397989, 84.983030329649083, 1.0], [228.48536167856011, 80.216827182028752, 1.0]]

# %% [markdown]
# Let's plot these data using the `IPmag.iplotDI` function.
#
#     Required Parameters
#     -----------
#     DIblock : a DIblock is comprised of a list of unit vectors [dec,inc,1.]
#
#     Optional Parameters
#     -----------
#     color : the default color is black. Other colors can be chosen (e.g. 'r')
#     marker : the default marker is a circle ('o')
#     label : the default label is blank ('')
#     legend : the default is no legend ('no'). Putting 'yes' will plot a legend.
#
# To use this function we need to first initialize a figure, use the `IPmag.iplotNET` function to generate a blank equal area plot and then use the `IPmag.iplotDI` function to plot the data on an equal area plot.

# %%
fignum = 1
plt.figure(num=fignum,figsize=(8,8),dpi=160)
IPmag.iplotNET(fignum)
IPmag.iplotDI(data)

# %% [markdown]
# ## Example taking a Fisher mean and plotting it using `IPmag.iplotDImean`

# %% [markdown]
# Let's use the set of directions developed above using using the `IPmag.ifishrot` function and use the `pmag.fisher_mean` function of PmagPy to calculate the Fisher mean. These data should have a mean that is approximately that specified in the call to the `IPmag.ifishrot` function above.

# %%
data_mean = pmag.fisher_mean(data)
data_mean
# Out:
# {'alpha95': 7.4098584404673922,
#  'csd': 17.94351465068695,
#  'dec': 243.71906915621702,
#  'inc': 86.394561143489582,
#  'k': 20.377692785395187,
#  'n': 20,
#  'r': 19.067607888680243}

# %% [markdown]
# The pmag.fisher_mean function returns a dictionary that gives the parameters associated with calculating a Fisher mean. These individual values can easily be called upon as is done in the cell below.

# %%
data_mean['dec']
# Out:
# 243.71906915621702

# %% [markdown]
# Let's plot this mean using the `IPmag.iplotDImean` function.
#
#     Required Parameters
#     -----------
#     Dec : declination of mean being plotted
#     Inc : inclination of mean being plotted
#     a95 : a95 confidence ellipse of mean being plotted
#
#     Optional Parameters
#     -----------
#     color : the default color is black. Other colors can be chosen (e.g. 'r')
#     marker : the default is a circle. Other symbols can be chose (e.g. 's')
#     label : the default is no label. Labels can be assigned.
#     legend : the default is no legend ('no'). Putting 'yes' will plot a legend.
#
# In addition to plotting the mean with its associated $\alpha_{95}$ confidence ellipse, we can plot the individual vectors too using the `IPmag.iplotDI` function. Let's customize the symbology and generate a legend as well.

# %%
fignum = 1
plt.figure(num=fignum,figsize=(8,8),dpi=160)
IPmag.iplotNET(fignum)
IPmag.iplotDI(data,color='g',label='data',legend='yes')
IPmag.iplotDImean(data_mean['dec'],data_mean['inc'],data_mean['alpha95'],
                  color='b',marker='s',label='mean of data',legend='yes')

# %% [markdown]
# ## Tests for a common mean (`IPmag.iWatsonV` and `IPmag.iBootstrap`)

# %%
data2 = IPmag.ifishrot(k=20,n=35,Dec=204,Inc=-30)
data2_mean = pmag.fisher_mean(data2)
data2_mean

data3 = IPmag.ifishrot(k=20,n=40,Dec=202,Inc=-20)
data3_mean = pmag.fisher_mean(data3)
data3_mean
# Out:
# {'alpha95': 5.5009696259784944,
#  'csd': 19.156992277659697,
#  'dec': 203.43109608790328,
#  'inc': -19.942333156076433,
#  'k': 17.877854129156876,
#  'n': 40,
#  'r': 37.818530136880625}

# %%
fignum = 1
plt.figure(num=fignum,figsize=(6,6),dpi=160)
IPmag.iplotNET(fignum)
#IPmag.iplotDI(data2,color='g',label='data 1',legend='yes')
#IPmag.iplotDI(data3,color='r',label='data 2',legend='yes')
IPmag.iplotDImean(data2_mean['dec'],data2_mean['inc'],data2_mean['alpha95'],
                  color='g',marker='s',label='mean of data 1',legend='yes')
IPmag.iplotDImean(data3_mean['dec'],data3_mean['inc'],data3_mean['alpha95'],
                  color='r',marker='s',label='mean of data 1',legend='yes')

# %%
#IPmag.iBootstrap(data2,data3)
IPmag.iWatsonV(data2,data3,NumSims=1000)
IPmag.iWatsonV?
# Out:
# Results of Watson V test:
#
# Watson's V:           4.4
# Critical value of V:  5.9
# "Pass": Since V is less than Vcrit, the null hypothesis
# that the two populations are drawn from distributions
# that share a common mean direction can not be rejected.
#
# M&M1990 classification:
#
# Angle between data set means: 3.8
# Critical angle for M&M1990:   4.3
# The McFadden and McElhinny (1990) classification for
# this test is: 'A'

# %% [markdown]
# ## Calculating and plotting virtual geomagnetic poles (`IPmag.vgpcalc`; `IPmag.vgpplot`) and mean poles (`IPmag.poleplot`)

# %% [markdown]
# ### Importing data and calculating poles using IPmag.vgpcalc

# %% [markdown]
# Let's import data from a study where there is published declination, inclination data from sites of given latitude.
#
# 	Author = {Symons, D.T.A.},
# 	Journal = {Canadian Journal of Earth Science},
# 	Pages = {1778-1783},
# 	Title = {{Paleomagnetism of the 1.1 Ga Lackner Lake Complex and tectonics of the Kapuskasing Structural Zone}},
# 	Volume = {26},
# 	Year = {1989}}
#
# A great way to import and wrangle with data in using pandas dataframes. The code block below uses the `pd.read_csv` function to input data from a .csv files into a dataframe.

# %%
Lackner_Data=pd.read_csv('Example_Data/Symons1989_Lackner_data.csv',sep=',')
Lackner_Data
# Out:
#           study  site  dec_tc  inc_tc  a95   n  site_lat  site_long   k  \
# 0   Symons1989a     1     315      59   10   6      47.8      -83.1  46
# 1   Symons1989a     2     322      46   13   9      47.8      -83.1  18
# 2   Symons1989a     3     299      59   12   7      47.8      -83.1  27
# 3   Symons1989a     4     303      52   10  10      47.8      -83.1  23
# 4   Symons1989a     5     307      55   11  10      47.8      -83.1  21
# 5   Symons1989a     6     301      75   14   8      47.8      -83.1  17
# 6   Symons1989a     7     280      65   11   8      47.8      -83.1  27
# 7   Symons1989a     8     282      72   11   6      47.8      -83.1  39
# 8   Symons1989a     9     301      74   11   7      47.8      -83.1  31
# 9   Symons1989a    10     295      67   12   9      47.8      -83.1  21
# 10  Symons1989a    11     279      79    8  10      47.8      -83.1  34
# 11  Symons1989a    12     312      59   10   9      47.8      -83.1  27
# 12  Symons1989a    15     310      65   15  10      47.8      -83.1  11
# 13  Symons1989a    16     307      51   15   9      47.8      -83.1  14
# 14  Symons1989a    17     323      62   12  10      47.8      -83.1  17
# 15  Symons1989a    18     322      78    8   9      47.8      -83.1  49
#
#    AF_demag_range(mT) T_demag_range(C)
# 0               15-30      none listed
# 1               15-30              450
# 2               15-50              560
# 3             22.5-50              530
# 4               15-60              500
# 5             22.5-50          560-580
# 6             22.5-35              560
# 7            22.5-130      none listed
# 8               15-50              560
# 9             22.5-80              560
# 10           22.5-130              590
# 11            22.5-75              560
# 12              20-30          400-590
# 13              20-50          300-560
# 14              20-25          530-580
# 15              20-40          400-560
#
# [16 rows x 11 columns]

# %% [markdown]
# We can pass this dataframe into the IPmag.vgpcalc function to calculate the virtual geomagnetic poles implied by the directional data and the site locations. This function requires there to be columns within the dataframe with the following names: 'dec_tc', 'inc_tc', 'site_lat' and 'site_long'. They must have those exact names for the function to work as currently written. Running this function will append 5 new columns to the dataframe: 'paleolatitude', 'pole_lat', 'pole_long', 'pole_lat_rev' and 'pole_long_rev'. The paleolatitude is calculated using the dipole formula while the '_rev' pole locations are the antipode from the 'pole_lat' and 'pole_long' in order to enable flexibility in the choice of polarity

# %%
IPmag.vgpcalc(Lackner_Data)
Lackner_Data
# Out:
#           study  site  dec_tc  inc_tc  a95   n  site_lat  site_long   k  \
# 0   Symons1989a     1     315      59   10   6      47.8      -83.1  46
# 1   Symons1989a     2     322      46   13   9      47.8      -83.1  18
# 2   Symons1989a     3     299      59   12   7      47.8      -83.1  27
# 3   Symons1989a     4     303      52   10  10      47.8      -83.1  23
# 4   Symons1989a     5     307      55   11  10      47.8      -83.1  21
# 5   Symons1989a     6     301      75   14   8      47.8      -83.1  17
# 6   Symons1989a     7     280      65   11   8      47.8      -83.1  27
# 7   Symons1989a     8     282      72   11   6      47.8      -83.1  39
# 8   Symons1989a     9     301      74   11   7      47.8      -83.1  31
# 9   Symons1989a    10     295      67   12   9      47.8      -83.1  21
# 10  Symons1989a    11     279      79    8  10      47.8      -83.1  34
# 11  Symons1989a    12     312      59   10   9      47.8      -83.1  27
# 12  Symons1989a    15     310      65   15  10      47.8      -83.1  11
# 13  Symons1989a    16     307      51   15   9      47.8      -83.1  14
# 14  Symons1989a    17     323      62   12  10      47.8      -83.1  17
# 15  Symons1989a    18     322      78    8   9      47.8      -83.1  49
#
#    AF_demag_range(mT) T_demag_range(C)  paleolatitude   pole_lat   pole_long  \
# 0               15-30      none listed      39.765187  57.029712  189.744793
# 1               15-30              450      27.373547  54.161247  165.929354
# 2               15-50              560      39.765187  46.400138  199.768970
# 3             22.5-50              530      32.618057  45.029083  188.703698
# 4               15-60              500      35.529645  49.418849  189.325647
# 5             22.5-50          560-580      61.813215  54.722902  232.388351
# 6             22.5-35              560      46.996928  38.412449  217.895005
# 7            22.5-130      none listed      56.982602  44.208187  228.865099
# 8               15-50              560      60.166127  54.561491  229.555572
# 9             22.5-80              560      49.670420  48.457508  214.715720
# 10           22.5-130              590      68.755879  46.763993  245.403217
# 11            22.5-75              560      39.765187  55.019233  191.766352
# 12              20-30          400-590      46.996928  56.746114  204.572758
# 13              20-50          300-560      31.693197  47.152295  184.671781
# 14              20-25          530-580      43.239577  63.935141  190.705306
# 15              20-40          400-560      66.969018  62.728347  245.187033
#
#     pole_lat_rev  pole_long_rev
# 0     -57.029712       9.744793
# 1     -54.161247     345.929354
# 2     -46.400138      19.768970
# 3     -45.029083       8.703698
# 4     -49.418849       9.325647
# 5     -54.722902      52.388351
# 6     -38.412449      37.895005
# 7     -44.208187      48.865099
# 8     -54.561491      49.555572
# 9     -48.457508      34.715720
# 10    -46.763993      65.403217
# 11    -55.019233      11.766352
# 12    -56.746114      24.572758
# 13    -47.152295       4.671781
# 14    -63.935141      10.705306
# 15    -62.728347      65.187033
#
# [16 rows x 16 columns]

# %%
Lackner_VGPs=[]
Lackner_Plong=[]
Lackner_Plat=[]
for n in range(0,len(Lackner_Data)): 
    Plong,Plat=Lackner_Data['pole_long'][n],Lackner_Data['pole_lat'][n]
    Lackner_Plong.append(Plong)
    Lackner_Plat.append(Plat)
    Lackner_VGPs.append([Plong,Plat,1.])

# %% [markdown]
# ### Plotting virtual geomagnetic and mean poles

# %% [markdown]
# To plot poles we first need a map projection. The matplotlib basemap package does a nice job of that, so let's import it:

# %%
from mpl_toolkits.basemap import Basemap

# %% [markdown]
# The basemap is highly customizable. A view from space type projection ('ortho') looks nice so let's use that one for this example. We will define an object ('m') that is a map projection and then draw additional things on the map such as continents and lat/long lines. Then let's extract the pole latitudes and pole longitudes from the Lackner data as lists and plot those using the `IPmag.vgpplot` function.
#
#     Required Parameters
#     -----------
#     mapname : the name of the current map that has been developed using basemap
#     plong : the longitude of the paleomagnetic pole being plotted (in degrees E)
#     plat : the latitude of the paleomagnetic pole being plotted (in degrees)
#
#     Optional Parameters
#     -----------
#     color : the color desired for the symbol and its A95 ellipse (default is 'k' aka black)
#     marker : the marker shape desired for the pole mean symbol (default is 'o' aka a circle)
#     label : the default is no label. Labels can be assigned.
#     legend : the default is no legend ('no'). Putting 'yes' will plot a legend.

# %%
plt.figure(figsize=(8, 8))
m = Basemap(projection='ortho',lat_0=35,lon_0=200,resolution='c',area_thresh=50000)
m.drawcoastlines(linewidth=0.25)
m.fillcontinents(color='bisque',lake_color='white',zorder=1)
m.drawmapboundary(fill_color='white')
m.drawmeridians(np.arange(0,360,30))
m.drawparallels(np.arange(-90,90,30))

Lackner_Plat = Lackner_Data['pole_lat'].tolist()
Lackner_Plong = Lackner_Data['pole_long'].tolist()

IPmag.vgpplot(m,Lackner_Plong,Lackner_Plat)
plt.show()

# %% [markdown]
# ### Calculate and plot mean pole

# %% [markdown]
# Creating a list of unit vectors allows for the Fisher mean to be calculated for the VGPs.

# %%
Lackner_VGPs=[]
for n in range(0,len(Lackner_Data)): 
    Plong,Plat=Lackner_Data['pole_long'][n],Lackner_Data['pole_lat'][n]
    Lackner_VGPs.append([Plong,Plat,1.])
    
Lackner_mean_pole=pmag.fisher_mean(Lackner_VGPs)

# %% [markdown]
# The `print` command can be used to print the mean parameters to the console. Note that the dictionary created by the `pmag.fisher_mean` command has default notation for directions rather than poles. In this case, `dec` in the dictionary is actually paleolongitude while `inc` is paleolatitude.

# %%
print 'The Fisher mean parameters for the pole are: '
print 'Plong = ' + str(Lackner_mean_pole['dec']) + ' Plat = ' + str(Lackner_mean_pole['inc'])
print 'A95 = ' + str(Lackner_mean_pole['alpha95']) + ' k= ' + str(Lackner_mean_pole['k'])
# Out:
# The Fisher mean parameters for the pole are:
# Plong = 207.471347171 Plat = 53.7187738088
# A95 = 7.28677036933 k= 26.5978601324

# %% [markdown]
# Now that the mean pole is calculated, it can be plotted using the `IPmag.poleplot` function. First, the same basemap as before will be created. After the basemap is created, the `IPmag.poleplot` function will be called.
#
#     Required Parameters
#     -----------
#     mapname : the name of the current map that has been developed using basemap
#     plong : the longitude of the paleomagnetic pole being plotted (in degrees E)
#     plat : the latitude of the paleomagnetic pole being plotted (in degrees)
#     A95 : the A_95 confidence ellipse of the paleomagnetic pole (in degrees)
#
#     Optional Parameters
#     -----------
#     label : a string that is the label for the paleomagnetic pole being plotted
#     color : the color desired for the symbol and its A95 ellipse (default is 'k' aka black)
#     marker : the marker shape desired for the pole mean symbol (default is 'o' aka a circle)
#     legend : the default is no legend ('no'). Putting 'yes' will plot a legend.

# %%
plt.figure(figsize=(8, 8))
m = Basemap(projection='ortho',lat_0=35,lon_0=200,resolution='c',area_thresh=50000)
m.drawcoastlines(linewidth=0.25)
m.fillcontinents(color='bisque',lake_color='white',zorder=1)
m.drawmapboundary(fill_color='white')
m.drawmeridians(np.arange(0,360,30))
m.drawparallels(np.arange(-90,90,30))

IPmag.poleplot(m,Lackner_mean_pole['dec'],Lackner_mean_pole['inc'],
               Lackner_mean_pole['alpha95'],label='Lackner mean pole',legend='yes')

# %% [markdown]
# ## Conducting tests for a common mean using the bootstrap test (`IPmag.iBootstrap`) and the Watson V test (`IPmag.iWatsonV`)

# %%
#IPmag.iBootstrap
#IPmag.iWatsonV

# %% [markdown]
# ## Reading data from MagIC format results files (`pmag.magic_read`)

# %% [markdown]
# PmagPy has built in functions to deal with data in MagIC database format files. One such function is the `pmag.magic_read` function. In the code block below, this function is used to read in data from a `pmag_results.txt` file. The `pmag.magic_read` function creates two outputs:
#
# 1. the data from the Magic template file in a list of dictionaries
# 2. the type of data in the file (e.g. 'pmag_results')

# %%
data,file_type=pmag.magic_read('Example_Data/pmag_results.txt')
data
# Out:
# [{'antipodal': '',
#   'average_age': '3.4',
#   'average_age_sigma': '0.03',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '2.3',
#   'average_dec': '330.1',
#   'average_inc': '64.9',
#   'average_int': '3.61e-05',
#   'average_int_n': '5',
#   'average_int_sigma': '1.32e-05',
#   'average_k': '572.7',
#   'average_lat': '42.6026',
#   'average_lat_sigma': '',
#   'average_lon': '245.602',
#   'average_lon_sigma': '',
#   'average_n': '8',
#   'average_nn': '8',
#   'average_r': '7.9878',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr01',
#   'er_specimen_names': 'sr01a1 : sr01a2 : sr01c2 : sr01d1 : sr01e2 : sr01f2 : sr01g2 : sr01i1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T:LP-PI-ALT-PTRM:LP-PI-TRM-ZI',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr01',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '6.05e+23',
#   'vadm_sigma': '8e+22',
#   'vgp_alpha95': '',
#   'vgp_dm': '4',
#   'vgp_dp': '2.7',
#   'vgp_lat': '68.5',
#   'vgp_lon': '177.3',
#   'vgp_n': '8'},
#  {'antipodal': '',
#   'average_age': '1',
#   'average_age_sigma': '1',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '3',
#   'average_dec': '151.8',
#   'average_inc': '-57.5',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '408.8',
#   'average_lat': '42.6035',
#   'average_lat_sigma': '',
#   'average_lon': '245.599',
#   'average_lon_sigma': '',
#   'average_n': '7',
#   'average_nn': '7',
#   'average_r': '6.9853',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr03',
#   'er_specimen_names': 'sr03a1 : sr03c1 : sr03e1 : sr03f1 : sr03g1 : sr03h2 : sr03k1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr03',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '4.1',
#   'vgp_dp': '3.6',
#   'vgp_lat': '-68.2',
#   'vgp_lon': '333.3',
#   'vgp_n': '7'},
#  {'antipodal': '',
#   'average_age': '2',
#   'average_age_sigma': '0.05',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '4.3',
#   'average_dec': '16.5',
#   'average_inc': '54.6',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '313.1',
#   'average_lat': '42.601',
#   'average_lat_sigma': '',
#   'average_lon': '245.596',
#   'average_lon_sigma': '',
#   'average_n': '5',
#   'average_nn': '5',
#   'average_r': '4.9872',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr04',
#   'er_specimen_names': 'sr04d2 : sr04e1 : sr04f2 : sr04g1 : sr04h3',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr04',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '5.5',
#   'vgp_dp': '5.1',
#   'vgp_lat': '75.2',
#   'vgp_lon': '0.4',
#   'vgp_n': '5'},
#  {'antipodal': '',
#   'average_age': '0.095',
#   'average_age_sigma': '0.05',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '3',
#   'average_dec': '14.6',
#   'average_inc': '77.9',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '407.3',
#   'average_lat': '42.7366',
#   'average_lat_sigma': '',
#   'average_lon': '245.165',
#   'average_lon_sigma': '',
#   'average_n': '7',
#   'average_nn': '7',
#   'average_r': '6.9865',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr09',
#   'er_specimen_names': 'sr09b2 : sr09c3 : sr09e2 : sr09f1 : sr09f2 : sr09g1 : sr09i1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr09',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '10.5',
#   'vgp_dp': '3.6',
#   'vgp_lat': '64.7',
#   'vgp_lon': '258.6',
#   'vgp_n': '7'},
#  {'antipodal': '',
#   'average_age': '0.395',
#   'average_age_sigma': '0.01',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '3',
#   'average_dec': '346.3',
#   'average_inc': '73.8',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '428.4',
#   'average_lat': '42.8418',
#   'average_lat_sigma': '',
#   'average_lon': '245.112',
#   'average_lon_sigma': '',
#   'average_n': '7',
#   'average_nn': '7',
#   'average_r': '6.9883',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr11',
#   'er_specimen_names': 'sr11a1 : sr11b1 : sr11c1 : sr11e2 : sr11f1 : sr11g2 : sr11i1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr11',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '7.9',
#   'vgp_dp': '3.6',
#   'vgp_lat': '71.1',
#   'vgp_lon': '223.6',
#   'vgp_n': '7'},
#  {'antipodal': '',
#   'average_age': '0.373',
#   'average_age_sigma': '0.06',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '5.1',
#   'average_dec': '15.3',
#   'average_inc': '44.8',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '227.8',
#   'average_lat': '42.8657',
#   'average_lat_sigma': '',
#   'average_lon': '245.127',
#   'average_lon_sigma': '',
#   'average_n': '5',
#   'average_nn': '5',
#   'average_r': '4.9824',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr12',
#   'er_specimen_names': 'sr12a3 : sr12b1 : sr12c1 : sr12e1 : sr12h1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr12',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '5.3',
#   'vgp_dp': '6.1',
#   'vgp_lat': '69.3',
#   'vgp_lon': '23',
#   'vgp_n': '5'},
#  {'antipodal': '',
#   'average_age': '0.404',
#   'average_age_sigma': '0.07',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '4',
#   'average_dec': '347.4',
#   'average_inc': '65.6',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '228.8',
#   'average_lat': '42.9203',
#   'average_lat_sigma': '',
#   'average_lon': '244.923',
#   'average_lon_sigma': '',
#   'average_n': '7',
#   'average_nn': '7',
#   'average_r': '6.9738',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr16',
#   'er_specimen_names': 'sr16a1 : sr16b1 : sr16c1 : sr16d1 : sr16e1 : sr16f1 : sr16g2',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr16',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '7.1',
#   'vgp_dp': '4.8',
#   'vgp_lat': '79.9',
#   'vgp_lon': '188.1',
#   'vgp_n': '7'},
#  {'antipodal': '',
#   'average_age': '1.76',
#   'average_age_sigma': '0.016',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '2.6',
#   'average_dec': '172.5',
#   'average_inc': '-66.9',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '892.1',
#   'average_lat': '42.4996',
#   'average_lat_sigma': '',
#   'average_lon': '245.851',
#   'average_lon_sigma': '',
#   'average_n': '5',
#   'average_nn': '5',
#   'average_r': '4.9955',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr21',
#   'er_specimen_names': 'sr21b2 : sr21d1 : sr21g2 : sr21h1 : sr21j2',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr21',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '4.9',
#   'vgp_dp': '3.1',
#   'vgp_lat': '-81.3',
#   'vgp_lon': '32',
#   'vgp_n': '5'},
#  {'antipodal': '',
#   'average_age': '2.26',
#   'average_age_sigma': '0.05',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '3.3',
#   'average_dec': '6.3',
#   'average_inc': '29.7',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '333.8',
#   'average_lat': '42.5',
#   'average_lat_sigma': '',
#   'average_lon': '245.85',
#   'average_lon_sigma': '',
#   'average_n': '7',
#   'average_nn': '7',
#   'average_r': '6.9835',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr22',
#   'er_specimen_names': 'sr22a1 : sr22b2 : sr22d3 : sr22e1 : sr22f1 : sr22g1 : sr22i2',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr22',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '2.8',
#   'vgp_dp': '3.9',
#   'vgp_lat': '62.9',
#   'vgp_lon': '52.5',
#   'vgp_n': '7'},
#  {'antipodal': '',
#   'average_age': '1.69',
#   'average_age_sigma': '0.02',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '2.5',
#   'average_dec': '14.5',
#   'average_inc': '45.5',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '970.1',
#   'average_lat': '42.5287',
#   'average_lat_sigma': '',
#   'average_lon': '245.979',
#   'average_lon_sigma': '',
#   'average_n': '5',
#   'average_nn': '5',
#   'average_r': '4.9964',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr23',
#   'er_specimen_names': 'sr23a1 : sr23b2 : sr23d3 : sr23f1 : sr23g1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr23',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '2.6',
#   'vgp_dp': '3',
#   'vgp_lat': '70.5',
#   'vgp_lon': '24.1',
#   'vgp_n': '5'},
#  {'antipodal': '',
#   'average_age': '0.591',
#   'average_age_sigma': '0.015',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '4.2',
#   'average_dec': '163.3',
#   'average_inc': '-62.2',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '325.7',
#   'average_lat': '42.4556',
#   'average_lat_sigma': '',
#   'average_lon': '245.636',
#   'average_lon_sigma': '',
#   'average_n': '5',
#   'average_nn': '5',
#   'average_r': '4.9877',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr24',
#   'er_specimen_names': 'sr24a1 : sr24b3 : sr24c2 : sr24d1 : sr24i2',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr24',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '6.6',
#   'vgp_dp': '5',
#   'vgp_lat': '-77.8',
#   'vgp_lon': '346.1',
#   'vgp_n': '5'},
#  {'antipodal': '',
#   'average_age': '0.291',
#   'average_age_sigma': '0.016',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '2.6',
#   'average_dec': '2.9',
#   'average_inc': '61.9',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '872.4',
#   'average_lat': '42.4892',
#   'average_lat_sigma': '',
#   'average_lon': '245.6',
#   'average_lon_sigma': '',
#   'average_n': '5',
#   'average_nn': '5',
#   'average_r': '4.9954',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr25',
#   'er_specimen_names': 'sr25b2 : sr25d2 : sr25e2 : sr25f3 : sr25h1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr25',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '4.1',
#   'vgp_dp': '3.1',
#   'vgp_lat': '87.8',
#   'vgp_lon': '318.1',
#   'vgp_n': '5'},
#  {'antipodal': '',
#   'average_age': '1.73',
#   'average_age_sigma': '0.01',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '4.9',
#   'average_dec': '358.6',
#   'average_inc': '62.5',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '153.9',
#   'average_lat': '42.4619',
#   'average_lat_sigma': '',
#   'average_lon': '245.615',
#   'average_lon_sigma': '',
#   'average_n': '7',
#   'average_nn': '7',
#   'average_r': '6.9643',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr26',
#   'er_specimen_names': 'sr26a3 : sr26b2 : sr26c3 : sr26e2 : sr26e3 : sr26f1 : sr26i1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr26',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '7.8',
#   'vgp_dp': '5.8',
#   'vgp_lat': '88.3',
#   'vgp_lon': '209.7',
#   'vgp_n': '7'},
#  {'antipodal': '',
#   'average_age': '2.94',
#   'average_age_sigma': '0.025',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '3.2',
#   'average_dec': '197.4',
#   'average_inc': '-51.2',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '296.1',
#   'average_lat': '42.6529',
#   'average_lat_sigma': '',
#   'average_lon': '246.988',
#   'average_lon_sigma': '',
#   'average_n': '8',
#   'average_nn': '8',
#   'average_r': '7.9764',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr28',
#   'er_specimen_names': 'sr28a1 : sr28b1 : sr28c1 : sr28c2 : sr28e1 : sr28f1 : sr28g2 : sr28h1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr28',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '3.8',
#   'vgp_dp': '3.8',
#   'vgp_lat': '-72.5',
#   'vgp_lon': '189.3',
#   'vgp_n': '8'},
#  {'antipodal': '',
#   'average_age': '1',
#   'average_age_sigma': '1',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '1.6',
#   'average_dec': '9.5',
#   'average_inc': '62.8',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '1253.3',
#   'average_lat': '43.305',
#   'average_lat_sigma': '',
#   'average_lon': '247.732',
#   'average_lon_sigma': '',
#   'average_n': '8',
#   'average_nn': '8',
#   'average_r': '7.9944',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr29',
#   'er_specimen_names': 'sr29a1 : sr29a2 : sr29b1 : sr29c1 : sr29e3 : sr29g1 : sr29g2 : sr29h1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr29',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '2.5',
#   'vgp_dp': '1.9',
#   'vgp_lat': '83.1',
#   'vgp_lon': '326.9',
#   'vgp_n': '8'},
#  {'antipodal': '',
#   'average_age': '5.75',
#   'average_age_sigma': '0.125',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '2.7',
#   'average_dec': '7.5',
#   'average_inc': '66.7',
#   'average_int': '4.88e-05',
#   'average_int_n': '2',
#   'average_int_sigma': '1.7e-06',
#   'average_k': '488.7',
#   'average_lat': '43.3682',
#   'average_lat_sigma': '',
#   'average_lon': '247.345',
#   'average_lon_sigma': '',
#   'average_n': '7',
#   'average_nn': '7',
#   'average_r': '6.9877',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr30',
#   'er_specimen_names': 'sr30a1 : sr30a2 : sr30b2 : sr30c1 : sr30d2 : sr30e1 : sr30i1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T:LP-PI-ALT-PTRM:LP-PI-TRM-ZI',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr30',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '8.11e+23',
#   'vadm_sigma': '1.33e+23',
#   'vgp_alpha95': '',
#   'vgp_dm': '5',
#   'vgp_dp': '3.3',
#   'vgp_lat': '82.2',
#   'vgp_lon': '286',
#   'vgp_n': '7'},
#  {'antipodal': '',
#   'average_age': '0.184',
#   'average_age_sigma': '0.014',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '1.3',
#   'average_dec': '23.2',
#   'average_inc': '54',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '1820.7',
#   'average_lat': '43.4213',
#   'average_lat_sigma': '',
#   'average_lon': '247.256',
#   'average_lon_sigma': '',
#   'average_n': '8',
#   'average_nn': '8',
#   'average_r': '7.9962',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr31',
#   'er_specimen_names': 'sr31a1 : sr31a2 : sr31b1 : sr31b3 : sr31c1 : sr31d1 : sr31f1 : sr31h2',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr31',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '1.6',
#   'vgp_dp': '1.6',
#   'vgp_lat': '70',
#   'vgp_lon': '355.8',
#   'vgp_n': '8'},
#  {'antipodal': '',
#   'average_age': '0.191',
#   'average_age_sigma': '0.008',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '2.4',
#   'average_dec': '205.8',
#   'average_inc': '-49.4',
#   'average_int': '7.85e-05',
#   'average_int_n': '3',
#   'average_int_sigma': '4.7e-06',
#   'average_k': '642.1',
#   'average_lat': '43.8859',
#   'average_lat_sigma': '',
#   'average_lon': '247.199',
#   'average_lon_sigma': '',
#   'average_n': '7',
#   'average_nn': '7',
#   'average_r': '6.9914',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr34',
#   'er_specimen_names': 'sr34a1 : sr34c1 : sr34f2 : sr34f3 : sr34i3 : sr34j1 : sr34k1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T:LP-PI-ALT-PTRM:LP-PI-TRM-ZI',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr34',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '1.3e+24',
#   'vadm_sigma': '7.8e+22',
#   'vgp_alpha95': '',
#   'vgp_dm': '2.7',
#   'vgp_dp': '2.9',
#   'vgp_lat': '-65.5',
#   'vgp_lon': '182.3',
#   'vgp_n': '7'},
#  {'antipodal': '',
#   'average_age': '0.124',
#   'average_age_sigma': '0.039',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '5.7',
#   'average_dec': '197.6',
#   'average_inc': '-65.5',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '138.9',
#   'average_lat': '43.8427',
#   'average_lat_sigma': '',
#   'average_lon': '247.376',
#   'average_lon_sigma': '',
#   'average_n': '6',
#   'average_nn': '6',
#   'average_r': '5.964',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr36',
#   'er_specimen_names': 'sr36a2 : sr36b1 : sr36c1 : sr36d1 : sr36e1 : sr36i2',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr36',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '9.9',
#   'vgp_dp': '7',
#   'vgp_lat': '-77.2',
#   'vgp_lon': '133.9',
#   'vgp_n': '6'},
#  {'antipodal': '',
#   'average_age': '1',
#   'average_age_sigma': '1',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '5.2',
#   'average_dec': '188.1',
#   'average_inc': '-47.2',
#   'average_int': '5.02e-05',
#   'average_int_n': '2',
#   'average_int_sigma': '2.7e-06',
#   'average_k': '168.2',
#   'average_lat': '43.5749',
#   'average_lat_sigma': '',
#   'average_lon': '248.266',
#   'average_lon_sigma': '',
#   'average_n': '6',
#   'average_nn': '6',
#   'average_r': '5.9703',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr39',
#   'er_specimen_names': 'sr39a1 : sr39b1 : sr39g3 : sr39h3 : sr39i1 : sr39j2',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T:LP-PI-ALT-PTRM:LP-PI-TRM-ZI',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr39',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '8.32e+23',
#   'vadm_sigma': '2.2e+22',
#   'vgp_alpha95': '',
#   'vgp_dm': '5.5',
#   'vgp_dp': '6.3',
#   'vgp_lat': '-73.5',
#   'vgp_lon': '222.4',
#   'vgp_n': '6'},
#  {'antipodal': '',
#   'average_age': '1',
#   'average_age_sigma': '1',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '4.2',
#   'average_dec': '192.9',
#   'average_inc': '-60.7',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '335',
#   'average_lat': '44.1566',
#   'average_lat_sigma': '',
#   'average_lon': '248.574',
#   'average_lon_sigma': '',
#   'average_n': '5',
#   'average_nn': '5',
#   'average_r': '4.9881',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'i',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr40',
#   'er_specimen_names': 'sr40a1 : sr40c2 : sr40e1 : sr40f3 : sr40g1',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'sr40',
#   'result_description': 'Site VGP.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '0',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '',
#   'vgp_dm': '6.2',
#   'vgp_dp': '5.2',
#   'vgp_lat': '-80.3',
#   'vgp_lon': '168.7',
#   'vgp_n': '5'},
#  {'antipodal': '',
#   'average_age': '1.5055',
#   'average_age_sigma': '1.6253',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '7.7',
#   'average_dec': '6.1',
#   'average_inc': '59.6',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '30.2',
#   'average_lat': '42.8154',
#   'average_lat_sigma': '0.346',
#   'average_lon': '245.9077',
#   'average_lon_sigma': '0.9269',
#   'average_n': '13',
#   'average_nn': '',
#   'average_r': '12.602',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'a',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr01 : sr04 : sr09 : sr11 : sr12 : sr16 : sr22 : sr23 : sr25 : sr26 : sr29 : sr30 : sr31',
#   'er_specimen_names': '',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '0',
#   'pmag_criteria_codes': 'DE-SITE : NPOLE',
#   'pmag_result_name': 'Normal Pole',
#   'result_description': 'Mean of normal directions.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '9.1',
#   'vgp_dm': '',
#   'vgp_dp': '',
#   'vgp_lat': '86.2',
#   'vgp_lon': '340.8',
#   'vgp_n': '13'},
#  {'antipodal': '',
#   'average_age': '1.0757',
#   'average_age_sigma': '0.91686',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '8.7',
#   'average_dec': '185.1',
#   'average_inc': '-58.8',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '41.9',
#   'average_lat': '43.225',
#   'average_lat_sigma': '0.7166',
#   'average_lon': '246.95',
#   'average_lon_sigma': '1.1686',
#   'average_n': '8',
#   'average_nn': '',
#   'average_r': '7.833',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'a',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr03 : sr21 : sr24 : sr28 : sr34 : sr36 : sr39 : sr40',
#   'er_specimen_names': '',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '100',
#   'pmag_criteria_codes': 'DE-SITE : RPOLE',
#   'pmag_result_name': 'Reverse pole',
#   'result_description': 'Mean of reverse directions.',
#   'reversal_test': 'ND',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '11.7',
#   'vgp_dm': '',
#   'vgp_dp': '',
#   'vgp_lat': '-85.5',
#   'vgp_lon': '199.3',
#   'vgp_n': '8'},
#  {'antipodal': '177.2',
#   'average_age': '1.3418',
#   'average_age_sigma': '1.3874',
#   'average_age_unit': 'Ma',
#   'average_alpha95': '5.4',
#   'average_dec': '5.7',
#   'average_inc': '59.3',
#   'average_int': '',
#   'average_int_n': '',
#   'average_int_sigma': '',
#   'average_k': '35.4',
#   'average_lat': '42.9714',
#   'average_lat_sigma': '0.5414',
#   'average_lon': '246.3048',
#   'average_lon_sigma': '1.1236',
#   'average_n': '21',
#   'average_nn': '',
#   'average_r': '20.4344',
#   'conglomerate_test': 'ND',
#   'contact_test': 'ND',
#   'data_type': 'a',
#   'er_citation_names': 'This study',
#   'er_location_names': 'Snake River',
#   'er_site_names': 'sr01 : sr03 : sr04 : sr09 : sr11 : sr12 : sr16 : sr21 : sr22 : sr23 : sr24 : sr25 : sr26 : sr28 : sr29 : sr30 : sr31 : sr34 : sr36 : sr39 : sr40',
#   'er_specimen_names': '',
#   'fold_test': 'ND',
#   'magic_method_codes': 'GM-ARAR-AP:LP-DC5:LP-DIR-AF:LP-DIR-T',
#   'percent_reversed': '38',
#   'pmag_criteria_codes': 'DE-SITE',
#   'pmag_result_name': 'Grand Mean pole',
#   'result_description': 'Grand Mean of all directions.',
#   'reversal_test': '+',
#   'rock_magnetic_test': 'ND',
#   'tilt_correction': '',
#   'vadm': '',
#   'vadm_sigma': '',
#   'vgp_alpha95': '6.7',
#   'vgp_dm': '',
#   'vgp_dp': '',
#   'vgp_lat': '86.1',
#   'vgp_lon': '357',
#   'vgp_n': '21'}]

# %% [markdown]
# Lists of dictionaries can be easily turned into a pandas dataframe simply by using the `pd.DataFrame`

# %%
results = pd.DataFrame(data)
#for some reason that data are all strings rather than floats
#at the moment these columns can be converted to floats
results.average_dec = results.average_dec.astype(float)
results.average_inc = results.average_inc.astype(float)
results.average_alpha95 = results.average_alpha95.astype(float)
results
# Out:
#    antipodal average_age average_age_sigma average_age_unit  average_alpha95  \
# 0                    3.4              0.03               Ma              2.3
# 1                      1                 1               Ma              3.0
# 2                      2              0.05               Ma              4.3
# 3                  0.095              0.05               Ma              3.0
# 4                  0.395              0.01               Ma              3.0
# 5                  0.373              0.06               Ma              5.1
# 6                  0.404              0.07               Ma              4.0
# 7                   1.76             0.016               Ma              2.6
# 8                   2.26              0.05               Ma              3.3
# 9                   1.69              0.02               Ma              2.5
# 10                 0.591             0.015               Ma              4.2
# 11                 0.291             0.016               Ma              2.6
# 12                  1.73              0.01               Ma              4.9
# 13                  2.94             0.025               Ma              3.2
# 14                     1                 1               Ma              1.6
# 15                  5.75             0.125               Ma              2.7
# 16                 0.184             0.014               Ma              1.3
# 17                 0.191             0.008               Ma              2.4
# 18                 0.124             0.039               Ma              5.7
# 19                     1                 1               Ma              5.2
# 20                     1                 1               Ma              4.2
# 21                1.5055            1.6253               Ma              7.7
# 22                1.0757           0.91686               Ma              8.7
# 23     177.2      1.3418            1.3874               Ma              5.4
#
#     average_dec  average_inc average_int average_int_n average_int_sigma  \
# 0         330.1         64.9    3.61e-05             5          1.32e-05
# 1         151.8        -57.5
# 2          16.5         54.6
# 3          14.6         77.9
# 4         346.3         73.8
# 5          15.3         44.8
# 6         347.4         65.6
# 7         172.5        -66.9
# 8           6.3         29.7
# 9          14.5         45.5
# 10        163.3        -62.2
# 11          2.9         61.9
# 12        358.6         62.5
# 13        197.4        -51.2
# 14          9.5         62.8
# 15          7.5         66.7    4.88e-05             2           1.7e-06
# 16         23.2         54.0
# 17        205.8        -49.4    7.85e-05             3           4.7e-06
# 18        197.6        -65.5
# 19        188.1        -47.2    5.02e-05             2           2.7e-06
# 20        192.9        -60.7
# 21          6.1         59.6
# 22        185.1        -58.8
# 23          5.7         59.3
#
#    average_k average_lat average_lat_sigma average_lon average_lon_sigma  \
# 0      572.7     42.6026                       245.602
# 1      408.8     42.6035                       245.599
# 2      313.1      42.601                       245.596
# 3      407.3     42.7366                       245.165
# 4      428.4     42.8418                       245.112
# 5      227.8     42.8657                       245.127
# 6      228.8     42.9203                       244.923
# 7      892.1     42.4996                       245.851
# 8      333.8        42.5                        245.85
# 9      970.1     42.5287                       245.979
# 10     325.7     42.4556                       245.636
# 11     872.4     42.4892                         245.6
# 12     153.9     42.4619                       245.615
# 13     296.1     42.6529                       246.988
# 14    1253.3      43.305                       247.732
# 15     488.7     43.3682                       247.345
# 16    1820.7     43.4213                       247.256
# 17     642.1     43.8859                       247.199
# 18     138.9     43.8427                       247.376
# 19     168.2     43.5749                       248.266
# 20       335     44.1566                       248.574
# 21      30.2     42.8154             0.346    245.9077            0.9269
# 22      41.9      43.225            0.7166      246.95            1.1686
# 23      35.4     42.9714            0.5414    246.3048            1.1236
#
#    average_n average_nn average_r conglomerate_test contact_test
# 0          8          8    7.9878                ND           ND ...
# 1          7          7    6.9853                ND           ND ...
# 2          5          5    4.9872                ND           ND ...
# 3          7          7    6.9865                ND           ND ...
# 4          7          7    6.9883                ND           ND ...
# 5          5          5    4.9824                ND           ND ...
# 6          7          7    6.9738                ND           ND ...
# 7          5          5    4.9955                ND           ND ...
# 8          7          7    6.9835                ND           ND ...
# 9          5          5    4.9964                ND           ND ...
# 10         5          5    4.9877                ND           ND ...
# 11         5          5    4.9954                ND           ND ...
# 12         7          7    6.9643                ND           ND ...
# 13         8          8    7.9764                ND           ND ...
# 14         8          8    7.9944                ND           ND ...
# 15         7          7    6.9877                ND           ND ...
# 16         8          8    7.9962                ND           ND ...
# 17         7          7    6.9914                ND           ND ...
# 18         6          6     5.964                ND           ND ...
# 19         6          6    5.9703                ND           ND ...
# 20         5          5    4.9881                ND           ND ...
# 21        13               12.602                ND           ND ...
# 22         8                7.833                ND           ND ...
# 23        21              20.4344                ND           ND ...
#
# [24 rows x 42 columns]

# %% [markdown]
# Now that we have imported the data, we can do other things with it such as plot it using `IPmag.iplotDImean`.

# %%
fignum = 1
plt.figure(num=fignum,figsize=(6,6),dpi=160)
IPmag.iplotNET(fignum)
for n in range(0,len(results)):
    IPmag.iplotDImean(results['average_dec'][n],results['average_inc'][n],results['average_alpha95'][n],
                  color='b',marker='s',label='mean of data',legend='no')
